# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np;

# %%
df=pd.read_csv(r"file/npl_ball_by_ball.csv")
df = df.apply(lambda col: col.str.lower() if col.dtype == "object" else col)
df.head(20)
# Out:
#     match_id        date   season  \
# 0    1462596  2024-11-30  2024/25
# 1    1462596  2024-11-30  2024/25
# 2    1462596  2024-11-30  2024/25
# 3    1462596  2024-11-30  2024/25
# 4    1462596  2024-11-30  2024/25
# 5    1462596  2024-11-30  2024/25
# 6    1462596  2024-11-30  2024/25
# 7    1462596  2024-11-30  2024/25
# 8    1462596  2024-11-30  2024/25
# 9    1462596  2024-11-30  2024/25
# 10   1462596  2024-11-30  2024/25
# 11   1462596  2024-11-30  2024/25
# 12   1462596  2024-11-30  2024/25
# 13   1462596  2024-11-30  2024/25
# 14   1462596  2024-11-30  2024/25
# 15   1462596  2024-11-30  2024/25
# 16   1462596  2024-11-30  2024/25
# 17   1462596  2024-11-30  2024/25
# 18   1462596  2024-11-30  2024/25
# 19   1462596  2024-11-30  2024/25
#
#                                                 venue  \
# 0   tribhuvan university international cricket gro...
# 1   tribhuvan university international cricket gro...
# 2   tribhuvan university international cricket gro...
# 3   tribhuvan university international cricket gro...
# 4   tribhuvan university international cricket gro...
# 5   tribhuvan university international cricket gro...
# 6   tribhuvan university international cricket gro...
# 7   tribhuvan university international cricket gro...
# 8   tribhuvan university international cricket gro...
# 9   tribhuvan university international cricket gro...
# 10  tribhuvan university international cricket gro...
# 11  tribhuvan university international cricket gro...
# 12  tribhuvan university international cricket gro...
# 13  tribhuvan university international cricket gro...
# 14  tribhuvan university international cricket gro...
# 15  tribhuvan university international cricket gro...
# 16  tribhuvan university international cricket gro...
# 17  tribhuvan university international cricket gro...
# 18  tribhuvan university international cricket gro...
# 19  tribhuvan university international cricket gro...
#
#                                      teams  over  ball      batter  \
# 0   ['biratnagar kings', 'janakpur bolts']     0     0  lokesh bam
# 1   ['biratnagar kings', 'janakpur bolts']     0     1  lokesh bam
# 2   ['biratnagar kings', 'janakpur bolts']     0     2  lokesh bam
# 3   ['biratnagar kings', 'janakpur bolts']     0     3  lokesh bam
# 4   ['biratnagar kings', 'janakpur bolts']     0     4  lokesh bam
# 5   ['biratnagar kings', 'janakpur bolts']     0     5  lokesh bam
# 6   ['biratnagar kings', 'janakpur bolts']     0     6  mj guptill
# 7   ['biratnagar kings', 'janakpur bolts']     1     0  lokesh bam
# 8   ['biratnagar kings', 'janakpur bolts']     1     1  aqib ilyas
# 9   ['biratnagar kings', 'janakpur bolts']     1     2  aqib ilyas
# 10  ['biratnagar kings', 'janakpur bolts']     1     3  aqib ilyas
# 11  ['biratnagar kings', 'janakpur bolts']     1     4  mj guptill
# 12  ['biratnagar kings', 'janakpur bolts']     1     5  mj guptill
# 13  ['biratnagar kings', 'janakpur bolts']     2     0  aqib ilyas
# 14  ['biratnagar kings', 'janakpur bolts']     2     1  mj guptill
# 15  ['biratnagar kings', 'janakpur bolts']     2     2  aqib ilyas
# 16  ['biratnagar kings', 'janakpur bolts']     2     3  mj guptill
# 17  ['biratnagar kings', 'janakpur bolts']     2     4  mj guptill
# 18  ['biratnagar kings', 'janakpur bolts']     2     5  mj guptill
# 19  ['biratnagar kings', 'janakpur bolts']     3     0  mj guptill
#
#    non_striker        bowler  runs_batter  runs_extras  runs_total  is_wicket  \
# 0   mj guptill      k mahato            0            0           0      False
# 1   mj guptill      k mahato            4            0           4      False
# 2   mj guptill      k mahato            0            0           0      False
# 3   mj guptill      k mahato            0            1           1      False
# 4   mj guptill      k mahato            0            0           0      False
# 5   mj guptill      k mahato            1            0           1      False
# 6   lokesh bam      k mahato            0            0           0      False
# 7   mj guptill  ln rajbanshi            0            0           0       True
# 8   mj guptill  ln rajbanshi            0            0           0      False
# 9   mj guptill  ln rajbanshi            0            0           0      False
# 10  mj guptill  ln rajbanshi            1            0           1      False
# 11  aqib ilyas  ln rajbanshi            0            0           0      False
# 12  aqib ilyas  ln rajbanshi            0            0           0      False
# 13  mj guptill      k mahato            1            0           1      False
# 14  aqib ilyas      k mahato            1            0           1      False
# 15  mj guptill      k mahato            1            0           1      False
# 16  aqib ilyas      k mahato            0            0           0      False
# 17  aqib ilyas      k mahato            0            0           0      False
# 18  aqib ilyas      k mahato            1            0           1      False
# 19  aqib ilyas  ln rajbanshi            0            0           0      False
#
#    wicket_kind  player_out           bowling_type
# 0          NaN         NaN  right arm medium fast
# 1          NaN         NaN  right arm medium fast
# 2          NaN         NaN  right arm medium fast
# 3          NaN         NaN  right arm medium fast
# 4          NaN         NaN  right arm medium fast
# 5          NaN         NaN  right arm medium fast
# 6          NaN         NaN  right arm medium fast
# 7       bowled  lokesh bam      left arm orthodox
# 8          NaN         NaN      left arm orthodox
# 9          NaN         NaN      left arm orthodox
# 10         NaN         NaN      left arm orthodox
# 11         NaN         NaN      left arm orthodox
# 12         NaN         NaN      left arm orthodox
# 13         NaN         NaN  right arm medium fast
# 14         NaN         NaN  right arm medium fast
# 15         NaN         NaN  right arm medium fast
# 16         NaN         NaN  right arm medium fast
# 17         NaN         NaN  right arm medium fast
# 18         NaN         NaN  right arm medium fast
# 19         NaN         NaN      left arm orthodox

# %%
df["bowling_type"].unique()
# Out:
# array(['right arm medium fast', 'left arm orthodox', 'right-arm legbreak',
#        'left arm wrist spin', 'right arm offbreak',
#        'right arm fast medium', 'left arm medium',
#        'right arm offbreak, legbreak googly', 'legbreak googly',
#        'slow left arm orthodox', 'left arm medium fast',
#        'right arm medium', 'right arm legbreak', 'right arm fast',
#        'right arm medium, right arm offbreak', 'left arm fast medium'],
#       dtype=object)

# %%
#best SR 
total_run=df.groupby("batter")["runs_batter"].sum()
total_run.sort_values(ascending=False,inplace=True)
balls_faced =df["batter"].value_counts()
batter_sr_df = pd.DataFrame({
    "runs": total_run,
    "balls_faced": balls_faced
})
batter_sr_df["strike_rate"] = (batter_sr_df["runs"] / batter_sr_df["balls_faced"]) * 100
batter_sr_df.sort_values(by="strike_rate", ascending=False, inplace=True)

batter_sr_df.head(30)
# Out:
#                  runs  balls_faced  strike_rate
# batter
# jds neesham       247          127   194.488189
# ags gous          225          138   163.043478
# nar sarki          22           14   157.142857
# ds airee          227          148   153.378378
# as routela         85           57   149.122807
# sc kuggeleijn      66           45   146.666667
# sompal kami        52           37   140.540541
# m levitt          102           75   136.000000
# b yadav           100           75   133.333333
# d kandel           12            9   133.333333
# harmeet singh      28           21   133.333333
# rs bopara         286          215   133.023256
# mg erasmus        110           83   132.530120
# saad bin zafar     83           63   131.746032
# sa zaib           275          212   129.716981
# rk paudel         279          218   127.981651
# karan kc           51           40   127.500000
# ja kolsawala       54           43   125.581395
# d gupta             5            4   125.000000
# hassan eisakhil   125          100   125.000000
# lokesh bam        131          105   124.761905
# bj mcmullen       201          162   124.074074
# tj moores         165          134   123.134328
# ma leask           44           36   122.222222
# r dhakal           22           18   122.222222
# nb budayair        28           23   121.739130
# bkel milantha     293          242   121.074380
# basir ahamad      181          152   119.078947
# wg bosisto        194          166   116.867470
# cb sole            35           30   116.666667

# %%
df["bowling_type"] = df["bowling_type"].replace("left arm orthodox", "slow left arm orthodox")

# %%
df.head(20)
# Out:
#     match_id        date   season  \
# 0    1462596  2024-11-30  2024/25
# 1    1462596  2024-11-30  2024/25
# 2    1462596  2024-11-30  2024/25
# 3    1462596  2024-11-30  2024/25
# 4    1462596  2024-11-30  2024/25
# 5    1462596  2024-11-30  2024/25
# 6    1462596  2024-11-30  2024/25
# 7    1462596  2024-11-30  2024/25
# 8    1462596  2024-11-30  2024/25
# 9    1462596  2024-11-30  2024/25
# 10   1462596  2024-11-30  2024/25
# 11   1462596  2024-11-30  2024/25
# 12   1462596  2024-11-30  2024/25
# 13   1462596  2024-11-30  2024/25
# 14   1462596  2024-11-30  2024/25
# 15   1462596  2024-11-30  2024/25
# 16   1462596  2024-11-30  2024/25
# 17   1462596  2024-11-30  2024/25
# 18   1462596  2024-11-30  2024/25
# 19   1462596  2024-11-30  2024/25
#
#                                                 venue  \
# 0   tribhuvan university international cricket gro...
# 1   tribhuvan university international cricket gro...
# 2   tribhuvan university international cricket gro...
# 3   tribhuvan university international cricket gro...
# 4   tribhuvan university international cricket gro...
# 5   tribhuvan university international cricket gro...
# 6   tribhuvan university international cricket gro...
# 7   tribhuvan university international cricket gro...
# 8   tribhuvan university international cricket gro...
# 9   tribhuvan university international cricket gro...
# 10  tribhuvan university international cricket gro...
# 11  tribhuvan university international cricket gro...
# 12  tribhuvan university international cricket gro...
# 13  tribhuvan university international cricket gro...
# 14  tribhuvan university international cricket gro...
# 15  tribhuvan university international cricket gro...
# 16  tribhuvan university international cricket gro...
# 17  tribhuvan university international cricket gro...
# 18  tribhuvan university international cricket gro...
# 19  tribhuvan university international cricket gro...
#
#                                      teams  over  ball      batter  \
# 0   ['biratnagar kings', 'janakpur bolts']     0     0  lokesh bam
# 1   ['biratnagar kings', 'janakpur bolts']     0     1  lokesh bam
# 2   ['biratnagar kings', 'janakpur bolts']     0     2  lokesh bam
# 3   ['biratnagar kings', 'janakpur bolts']     0     3  lokesh bam
# 4   ['biratnagar kings', 'janakpur bolts']     0     4  lokesh bam
# 5   ['biratnagar kings', 'janakpur bolts']     0     5  lokesh bam
# 6   ['biratnagar kings', 'janakpur bolts']     0     6  mj guptill
# 7   ['biratnagar kings', 'janakpur bolts']     1     0  lokesh bam
# 8   ['biratnagar kings', 'janakpur bolts']     1     1  aqib ilyas
# 9   ['biratnagar kings', 'janakpur bolts']     1     2  aqib ilyas
# 10  ['biratnagar kings', 'janakpur bolts']     1     3  aqib ilyas
# 11  ['biratnagar kings', 'janakpur bolts']     1     4  mj guptill
# 12  ['biratnagar kings', 'janakpur bolts']     1     5  mj guptill
# 13  ['biratnagar kings', 'janakpur bolts']     2     0  aqib ilyas
# 14  ['biratnagar kings', 'janakpur bolts']     2     1  mj guptill
# 15  ['biratnagar kings', 'janakpur bolts']     2     2  aqib ilyas
# 16  ['biratnagar kings', 'janakpur bolts']     2     3  mj guptill
# 17  ['biratnagar kings', 'janakpur bolts']     2     4  mj guptill
# 18  ['biratnagar kings', 'janakpur bolts']     2     5  mj guptill
# 19  ['biratnagar kings', 'janakpur bolts']     3     0  mj guptill
#
#    non_striker        bowler  runs_batter  runs_extras  runs_total  is_wicket  \
# 0   mj guptill      k mahato            0            0           0      False
# 1   mj guptill      k mahato            4            0           4      False
# 2   mj guptill      k mahato            0            0           0      False
# 3   mj guptill      k mahato            0            1           1      False
# 4   mj guptill      k mahato            0            0           0      False
# 5   mj guptill      k mahato            1            0           1      False
# 6   lokesh bam      k mahato            0            0           0      False
# 7   mj guptill  ln rajbanshi            0            0           0       True
# 8   mj guptill  ln rajbanshi            0            0           0      False
# 9   mj guptill  ln rajbanshi            0            0           0      False
# 10  mj guptill  ln rajbanshi            1            0           1      False
# 11  aqib ilyas  ln rajbanshi            0            0           0      False
# 12  aqib ilyas  ln rajbanshi            0            0           0      False
# 13  mj guptill      k mahato            1            0           1      False
# 14  aqib ilyas      k mahato            1            0           1      False
# 15  mj guptill      k mahato            1            0           1      False
# 16  aqib ilyas      k mahato            0            0           0      False
# 17  aqib ilyas      k mahato            0            0           0      False
# 18  aqib ilyas      k mahato            1            0           1      False
# 19  aqib ilyas  ln rajbanshi            0            0           0      False
#
#    wicket_kind  player_out            bowling_type
# 0          NaN         NaN   right arm medium fast
# 1          NaN         NaN   right arm medium fast
# 2          NaN         NaN   right arm medium fast
# 3          NaN         NaN   right arm medium fast
# 4          NaN         NaN   right arm medium fast
# 5          NaN         NaN   right arm medium fast
# 6          NaN         NaN   right arm medium fast
# 7       bowled  lokesh bam  slow left arm orthodox
# 8          NaN         NaN  slow left arm orthodox
# 9          NaN         NaN  slow left arm orthodox
# 10         NaN         NaN  slow left arm orthodox
# 11         NaN         NaN  slow left arm orthodox
# 12         NaN         NaN  slow left arm orthodox
# 13         NaN         NaN   right arm medium fast
# 14         NaN         NaN   right arm medium fast
# 15         NaN         NaN   right arm medium fast
# 16         NaN         NaN   right arm medium fast
# 17         NaN         NaN   right arm medium fast
# 18         NaN         NaN   right arm medium fast
# 19         NaN         NaN  slow left arm orthodox

# %%
valid_dismissals = ["bowled", "caught", "lbw", "stumped", "caught and bowled"]
df["is_bowler_wicket"] = df["wicket_kind"].isin(valid_dismissals)
matchups_bowling_type = (
    df.groupby(["batter", "bowling_type"])
    .agg(
        balls_faced=("batter", "count"),
        runs_scored=("runs_batter", "sum"),
        dismissals=("is_bowler_wicket", "sum")
    )
    .reset_index()
)
matchups_bowling_type["strike_rate"] = (matchups_bowling_type["runs_scored"] / matchups_bowling_type["balls_faced"]) * 100
matchups_bowling_type["strike_rate"] = matchups_bowling_type["strike_rate"].round(2)

matchups_bowling_type[matchups_bowling_type["bowling_type"]=="right arm offbreak"].sort_values(by=["runs_scored","strike_rate"],ascending=False).head(30)
# Out:
#               batter        bowling_type  balls_faced  runs_scored  \
# 349      jds neesham  right arm offbreak           31           77
# 569        rs bopara  right arm offbreak           41           65
# 187    bkel milantha  right arm offbreak           44           54
# 391     kushal malla  right arm offbreak           70           54
# 719        tj moores  right arm offbreak           36           51
# 650          sa zaib  right arm offbreak           43           48
# 108       b bhandari  right arm offbreak           41           47
# 199       cak walton  right arm offbreak           27           44
# 280         ds airee  right arm offbreak           33           40
# 541        rk paudel  right arm offbreak           30           32
# 176      bj mcmullen  right arm offbreak           28           29
# 9           a gharti  right arm offbreak           11           28
# 98        as routela  right arm offbreak           15           24
# 442       mj guptill  right arm offbreak           22           24
# 291       gulsan jha  right arm offbreak           34           23
# 318  hassan eisakhil  right arm offbreak           12           22
# 494        nr kirton  right arm offbreak           31           22
# 154     basir ahamad  right arm offbreak           27           19
# 608          s karki  right arm offbreak           12           18
# 591           s jora  right arm offbreak           23           18
# 761  zeeshan maqsood  right arm offbreak           11           17
# 327         i pandey  right arm offbreak           15           17
# 54      aarif sheikh  right arm offbreak           17           17
# 263    da douthwaite  right arm offbreak           11           16
# 522        ra reifer  right arm offbreak           20           16
# 397   lm benkenstein  right arm offbreak           10           15
# 84            ak sah  right arm offbreak           11           15
# 75          ags gous  right arm offbreak           14           15
# 246         d kharel  right arm offbreak           21           15
# 432       mg erasmus  right arm offbreak            7           14
#
#      dismissals  strike_rate
# 349           1       248.39
# 569           2       158.54
# 187           3       122.73
# 391           0        77.14
# 719           2       141.67
# 650           1       111.63
# 108           2       114.63
# 199           2       162.96
# 280           0       121.21
# 541           1       106.67
# 176           1       103.57
# 9             0       254.55
# 98            1       160.00
# 442           1       109.09
# 291           2        67.65
# 318           1       183.33
# 494           2        70.97
# 154           0        70.37
# 608           0       150.00
# 591           2        78.26
# 761           1       154.55
# 327           0       113.33
# 54            0       100.00
# 263           1       145.45
# 522           1        80.00
# 397           1       150.00
# 84            1       136.36
# 75            1       107.14
# 246           0        71.43
# 432           0       200.00

# %%
bowling_type_matchups=matchups_bowling_type.groupby("bowling_type").agg(
    total_ball_bowls=("balls_faced",'sum'),
    total_runs_given=("runs_scored",'sum'),
    total_dissmisals=("dismissals","sum")
)
bowling_type_matchups["strike_rate"]=(bowling_type_matchups["total_runs_given"] / bowling_type_matchups["total_ball_bowls"]) * 100
bowling_type_matchups.sort_values(by="strike_rate",ascending=False)
# Out:
#                                       total_ball_bowls  total_runs_given  \
# bowling_type
# left arm wrist spin                                 12                19
# right arm legbreak                                 321               415
# left arm fast medium                               152               186
# right arm medium fast                              617               750
# right arm medium                                   882              1058
# right arm offbreak, legbreak googly                 42                50
# legbreak googly                                    175               208
# left arm medium                                    300               341
# right arm medium, right arm offbreak               152               169
# left arm medium fast                               398               429
# right arm offbreak                                1091              1158
# right arm fast medium                              630               655
# slow left arm orthodox                            2368              2377
# right arm fast                                     150               145
# right-arm legbreak                                 208               199
#
#                                       total_dissmisals  strike_rate
# bowling_type
# left arm wrist spin                                  0   158.333333
# right arm legbreak                                  14   129.283489
# left arm fast medium                                 9   122.368421
# right arm medium fast                               33   121.555916
# right arm medium                                    38   119.954649
# right arm offbreak, legbreak googly                  1   119.047619
# legbreak googly                                      6   118.857143
# left arm medium                                     22   113.666667
# right arm medium, right arm offbreak                 9   111.184211
# left arm medium fast                                22   107.788945
# right arm offbreak                                  60   106.141155
# right arm fast medium                               39   103.968254
# slow left arm orthodox                             135   100.380068
# right arm fast                                      12    96.666667
# right-arm legbreak                                  12    95.673077

# %%
sns.histplot(bowling_type_matchups["strike_rate"],bins=9)
# Out:
# <Axes: xlabel='strike_rate', ylabel='Count'>

# %%
df["match_id"].nunique()
# Out:
# 32

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["is_wicket"].value_counts()
# Out:
# is_wicket
# False    7043
# True      455
# Name: count, dtype: int64

# %%
df["wicket_kind"].value_counts()
# Out:
# wicket_kind
# caught               224
# bowled                96
# lbw                   69
# run out               42
# stumped               14
# caught and bowled      9
# retired out            1
# Name: count, dtype: int64

# %%
df[df["bowling_type"].isna()]["bowler"].unique()
# Out:
# array([], dtype=object)

# %%
batter=df["batter"].unique()
batter
# Out:
# array(['lokesh bam', 'mj guptill', 'aqib ilyas', 'nr kirton',
#        'basir ahamad', 'rp magar', 'pratis gc', 's lamichhane', 'cb sole',
#        'jk mukhiya', 'a kharel', 'ak sah', 'aasif sheikh',
#        'bkel milantha', 'h thaker', 'ss eskinazi', 'm levitt',
#        's maharjan', 'mg erasmus', 'b sharki', 'shankar rana',
#        'rashid khan', 'da douthwaite', 'karan kc', 'shahab alam',
#        'd kandel', 'hassan eisakhil', 'deepak bohara', 'lm benkenstein',
#        'kushal malla', 'rs bopara', 's karki', 's vesawkar', 'd khanal',
#        's dhawan', 'cak walton', 'babar hayat', 'zeeshan maqsood',
#        'gulsan jha', 'a gharti', 'sompal kami', 'jds neesham',
#        'a shrestha', 'b bhandari', 'bj mcmullen', 'aarif sheikh',
#        'sa zaib', 'i pandey', 'ds airee', 'sc kuggeleijn', 'b khatri',
#        'ismat alam', 'd bohara', 'sohail tanvir', 'as routela',
#        'k bhurtel', 'd nath', 'bfw de leede', 'd kharel', 'k thagunna',
#        'ra reifer', 'ma leask', 'mjj critchley', 'n joshi',
#        'bipin khatri', 's dhakal', 'a ghiraiya', 'a saud', 'rk paudel',
#        'tj moores', 's jora', 'saad bin zafar', 'bcj cutting', 'b yadav',
#        'rr simmonds', 'ags gous', 'rohan mustafa', 'p shrestha',
#        'na sowter', 'b rawal', 'jn loftie-eaton', 'ubt chand',
#        'd adhikari', 'surya tamang', 'd gupta', 'wg bosisto', 'nk yadav',
#        'ubs thakuri', 'bp sharma', 'n bhatta', 's kansakar',
#        'mohammad mohsin', 's malla', 'h dhami', 'ln rajbanshi',
#        'ds bajwa', 'nb budayair', 'n saud', 'r dhakal', 'nar sarki',
#        'aakash chand', 'harmeet singh', 'a bohara', 'j tromp', 'a yadav',
#        'k mahato', 'abhishesh gautam', 'sa edwards', 'z malik', 'tr das',
#        'tr bhandari', 'basil hameed', 'aakarshit gomel',
#        'subash bhandari', 'rit gautam', 'ja kolsawala', 'a tripathi',
#        'mayan yadav'], dtype=object)

# %%
import pandas as pd

# Your batting_side_map dictionary (paste your full dictionary here)
batting_side_map = {
    'lokesh bam': 'R',
    'mj guptill': 'R',
    'aqib ilyas': 'R',
    'nr kirton': 'L',
    'basir ahamad': 'L',
    'rp magar': 'R',
    'pratis gc': 'R',
    's lamichhane': 'R',
    'cb sole': 'R',
    'jk mukhiya': 'R',
    'a kharel': 'R',
    'ak sah': 'R',
    'aasif sheikh': 'R',
    'bkel milantha': 'R',
    'h thaker': 'R',
    'ss eskinazi': 'R',
    'm levitt': 'R',
    's maharjan': 'L',
    'mg erasmus': 'R',
    'b sharki': 'R',
    'shankar rana': 'R',
    'rashid khan': 'R',
    'da douthwaite': 'R',
    'karan kc': 'R',
    'shahab alam': 'R',
    'd kandel': 'R',
    'hassan eisakhil': 'R',
    'deepak bohara': 'R',
    'lm benkenstein': 'R',
    'kushal malla': 'L',
    'rs bopara': 'R',
    's karki': 'R',
    's vesawkar': 'L',
    'd khanal': 'R',
    's dhawan': 'R',
    'cak walton': 'R',
    'babar hayat': 'L',
    'zeeshan maqsood': 'R',
    'gulsan jha': 'L',
    'a gharti': 'R',
    'sompal kami': 'R',
    'jds neesham': 'R',
    'a shrestha': 'R',
    'b bhandari': 'R',
    'bj mcmullen': 'R',
    'aarif sheikh': 'R',
    'sa zaib': 'R',
    'i pandey': 'R',
    'ds airee': 'R',
    'sc kuggeleijn': 'R',
    'b khatri': 'R',
    'ismat alam': 'R',
    'd bohara': 'R',
    'sohail tanvir': 'R',
    'as routela': 'R',
    'k bhurtel': 'R',
    'd nath': 'R',
    'bfw de leede': 'R',
    'd kharel': 'R',
    'k thagunna': 'R',
    'ra reifer': 'R',
    'ma leask': 'R',
    'mjj critchley': 'R',
    'n joshi': 'R',
    'bipin khatri': 'R',
    's dhakal': 'R',
    'a ghiraiya': 'R',
    'a saud': 'R',
    'rk paudel': 'R',
    'tj moores': 'R',
    's jora': 'R',
    'saad bin zafar': 'R',
    'bcj cutting': 'R',
    'b yadav': 'R',
    'rr simmonds': 'R',
    'ags gous': 'R',
    'rohan mustafa': 'R',
    'p shrestha': 'R',
    'na sowter': 'R',
    'b rawal': 'R',
    'jn loftie-eaton': 'R',
    'ubt chand': 'R',
    'd adhikari': 'R',
    'surya tamang': 'R',
    'd gupta': 'R',
    'wg bosisto': 'R',
    'nk yadav': 'R',
    'ubs thakuri': 'R',
    'bp sharma': 'R',
    'n bhatta': 'R',
    's kansakar': 'R',
    'mohammad mohsin': 'R',
    's malla': 'R',
    'h dhami': 'R',
    'ln rajbanshi': 'R',
    'ds bajwa': 'R',
    'nb budayair': 'R',
    'n saud': 'R',
    'r dhakal': 'R',
    'nar sarki': 'R',
    'aakash chand': 'R',
    'harmeet singh': 'R',
    'a bohara': 'R',
    'j tromp': 'R',
    'a yadav': 'R',
    'k mahato': 'R',
    'abhishesh gautam': 'R',
    'sa edwards': 'R',
    'z malik': 'R',
    'tr das': 'R',
    'tr bhandari': 'R',
    'basil hameed': 'R',
    'aakarshit gomel': 'R',
    'subash bhandari': 'R',
    'rit gautam': 'R',
    'ja kolsawala': 'R',
    'a tripathi': 'R',
    'mayan yadav': 'R',
}

# Load your CSV file
df = pd.read_csv(r'file/npl_ball_by_ball.csv')

# Normalize batsman names in the CSV (optional, to lowercase to match keys)
df['batsman_norm'] = df['batter'].str.lower().str.strip()

# Map batting side using the dictionary, default to 'Unknown' if not found
df['batting_side'] = df['batsman_norm'].map(batting_side_map).fillna('Unknown')

# Drop helper column
df.drop(columns=['batsman_norm'], inplace=True)

# Save updated CSV
df.to_csv('npl_ball_by_ball_with_batting_side.csv', index=False)

print("Updated CSV saved as 'npl_ball_by_ball_with_batting_side.csv'")
# Out:
# Updated CSV saved as 'npl_ball_by_ball_with_batting_side.csv'

# %%
df["batting_side"].unique()
# Out:
# array(['R', 'L'], dtype=object)
